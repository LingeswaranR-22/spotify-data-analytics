# %% [markdown]
# # Spotify Exploration
# Quick EDA on processed data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('../data/processed/spotify_analytics_dataset.csv')
df[['danceability','energy','valence','tempo','track_popularity']].hist(bins=20)
plt.show()

# %%
df.groupby('genre_primary')['track_id'].nunique().sort_values(ascending=False).head(10)
